# %%
import pandas as pd

# %%
data = pd.read_csv('regression.csv', encoding='latin-1')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   laptop_ID         1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   Product           1303 non-null   object
#  3   TypeName          1303 non-null   object
#  4   Inches            1303 non-null   float64
#  5   ScreenResolution  1303 non-null   object
#  6   Cpu               1303 non-null   object
#  7   Ram               1303 non-null   object
#  8   Memory            1303 non-null   object
#  9   Gpu               1303 non-null   object
#  10  OpSys             1303 non-null   object
#  11  Weight            1303 non-null   object
#  12  Price_euros       1303 non-null   float64
# dtypes: float64(2), int64(1), object(10)
# memory usage: 132.5+ KB

# %%
data
# Out:
#       laptop_ID Company                              Product  \
# 0             1   Apple                          MacBook Pro
# 1             2   Apple                          Macbook Air
# 2             3      HP                               250 G6
# 3             4   Apple                          MacBook Pro
# 4             5   Apple                          MacBook Pro
# ...         ...     ...                                  ...
# 1298       1316  Lenovo                       Yoga 500-14ISK
# 1299       1317  Lenovo                       Yoga 900-13ISK
# 1300       1318  Lenovo                   IdeaPad 100S-14IBR
# 1301       1319      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)
#
#                 TypeName  Inches                            ScreenResolution  \
# 0              Ultrabook    13.3          IPS Panel Retina Display 2560x1600
# ...

# %%
data_id = data[['laptop_ID', 'Product']]
data_id
# Out:
#       laptop_ID                              Product
# 0             1                          MacBook Pro
# 1             2                          Macbook Air
# 2             3                               250 G6
# 3             4                          MacBook Pro
# 4             5                          MacBook Pro
# ...         ...                                  ...
# 1298       1316                       Yoga 500-14ISK
# 1299       1317                       Yoga 900-13ISK
# 1300       1318                   IdeaPad 100S-14IBR
# 1301       1319  15-AC110nv (i7-6500U/6GB/1TB/Radeon
# 1302       1320  X553SA-XX031T (N3050/4GB/500GB/W10)
#
# [1303 rows x 2 columns]

# %%
del data['Product']

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                 ScreenResolution  \
# 0             IPS Panel Retina Display 2560x1600
# 1                                       1440x900
# 2                              Full HD 1920x1080
# 3             IPS Panel Retina Display 2880x1800
# 4             IPS Panel Retina Display 2560x1600
# ...

# %%
del data['ScreenResolution']

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu   Ram               Memory  \
# 0                     Intel Core i5 2.3GHz   8GB            128GB SSD
# 1                     Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# ...

# %% [markdown]
# ### Обработка Ram

# %%
data['Ram'] = data['Ram'].str.replace('GB', '').astype(int)

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# ...

# %% [markdown]
# ### Обработка Weight

# %%
data['Weight'] = data['Weight'].str.replace('kg', '').astype(float)

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# ...

# %% [markdown]
# ### Обработка Memory

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %%
data['Memory'].apply(lambda x : ' '.join(x.split(' ')[0:2]))
# Out:
# 0         128GB SSD
# 1       128GB Flash
# 2         256GB SSD
# 3         512GB SSD
# 4         256GB SSD
#            ...
# 1298      128GB SSD
# 1299      512GB SSD
# 1300     64GB Flash
# 1301        1TB HDD
# 1302      500GB HDD
# Name: Memory, Length: 1303, dtype: object

# %%
data['Memory_Type'] = data['Memory'].apply(lambda x : str(x.split(' ')[1]))

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu  Ram               Memory  \
# 0                     Intel Core i5 2.3GHz    8            128GB SSD
# 1                     Intel Core i5 1.8GHz    8  128GB Flash Storage
# 2               Intel Core i5 7200U 2.5GHz    8            256GB SSD
# ...

# %%
data['Memory'] = data['Memory'].apply(lambda x : str(x.split(' ')[0]))

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu  Ram Memory  \
# 0                     Intel Core i5 2.3GHz    8  128GB
# 1                     Intel Core i5 1.8GHz    8  128GB
# 2               Intel Core i5 7200U 2.5GHz    8  256GB
# 3                     Intel Core i7 2.7GHz   16  512GB
# 4                     Intel Core i5 3.1GHz    8  256GB
# ...

# %%
data['Memory'].value_counts()
# Out:
# Memory
# 256GB    508
# 1024     250
# 128GB    177
# 512GB    140
# 500GB    132
# 32GB      45
# 64GB      17
# 2048      16
# 16GB      10
# 180GB      5
# 240GB      1
# 8GB        1
# 508GB      1
# Name: count, dtype: int64

# %%
data.loc[data['Memory'] == '2TB', 'Memory'] = '2048'

# %%
data.loc[data['Memory'].str.contains('TB'), 'Memory'] = '1024'

# %%
data['Memory'] = data['Memory'].str.replace('GB', '')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   laptop_ID    1303 non-null   int64
#  1   Company      1303 non-null   object
#  2   TypeName     1303 non-null   object
#  3   Inches       1303 non-null   float64
#  4   Cpu          1303 non-null   object
#  5   Ram          1303 non-null   int64
#  6   Memory       1303 non-null   object
#  7   Gpu          1303 non-null   object
#  8   OpSys        1303 non-null   object
#  9   Weight       1303 non-null   float64
#  10  Price_euros  1303 non-null   float64
#  11  Memory_Type  1303 non-null   object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 122.3+ KB

# %%
data['Memory'] = data['Memory'].astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   laptop_ID    1303 non-null   int64
#  1   Company      1303 non-null   object
#  2   TypeName     1303 non-null   object
#  3   Inches       1303 non-null   float64
#  4   Cpu          1303 non-null   object
#  5   Ram          1303 non-null   int64
#  6   Memory       1303 non-null   int64
#  7   Gpu          1303 non-null   object
#  8   OpSys        1303 non-null   object
#  9   Weight       1303 non-null   float64
#  10  Price_euros  1303 non-null   float64
#  11  Memory_Type  1303 non-null   object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 122.3+ KB

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu  Ram  Memory  \
# 0                     Intel Core i5 2.3GHz    8     128
# 1                     Intel Core i5 1.8GHz    8     128
# 2               Intel Core i5 7200U 2.5GHz    8     256
# 3                     Intel Core i7 2.7GHz   16     512
# ...

# %% [markdown]
# ### Обрвботка OpSys

# %%
data['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         27
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %%
grouped = data.groupby('OpSys')['Price_euros'].mean()

# %%
grouped['Mac OS X']
# Out:
# 1262.87125

# %%
for system in data['OpSys'].unique():
    data.loc[data['OpSys'] == system, 'OpSys'] = grouped[system]

# %%
data
# Out:
#       laptop_ID Company            TypeName  Inches  \
# 0             1   Apple           Ultrabook    13.3
# 1             2   Apple           Ultrabook    13.3
# 2             3      HP            Notebook    15.6
# 3             4   Apple           Ultrabook    15.4
# 4             5   Apple           Ultrabook    13.3
# ...         ...     ...                 ...     ...
# 1298       1316  Lenovo  2 in 1 Convertible    14.0
# 1299       1317  Lenovo  2 in 1 Convertible    13.3
# 1300       1318  Lenovo            Notebook    14.0
# 1301       1319      HP            Notebook    15.6
# 1302       1320    Asus            Notebook    15.6
#
#                                        Cpu  Ram  Memory  \
# 0                     Intel Core i5 2.3GHz    8     128
# 1                     Intel Core i5 1.8GHz    8     128
# 2               Intel Core i5 7200U 2.5GHz    8     256
# 3                     Intel Core i7 2.7GHz   16     512
# ...

# %%
def target_encoding(data: pd.DataFrame, filling_value: str, target_value: str = 'Price_euros') -> pd.DataFrame:
    grouped = data.groupby(filling_value)[target_value].mean()
    temp = data.copy(deep=True)
    for item in temp[filling_value].unique():
        temp.loc[temp[filling_value] ==  item, filling_value] = grouped[item]
    return temp

# %% [markdown]
# ### Обработка Company

# %%
data = target_encoding(data, 'Company')

# %% [markdown]
# ### Обработка TypeName

# %%
data = target_encoding(data, 'TypeName')

# %% [markdown]
# ### Обработка Cpu

# %%
len(data['Cpu'].unique())
# Out:
# 40

# %%
data['Cpu'] = data['Cpu'].apply(lambda x: ' '.join(x.split(' ')[0:3]))

# %%
data
# Out:
#       laptop_ID      Company     TypeName  Inches          Cpu  Ram  Memory  \
# 0             1  1564.198571  1548.230357    13.3  1015.015248    8     128
# 1             2  1564.198571  1548.230357    13.3  1015.015248    8     128
# 2             3  1067.774854   782.078624    15.6  1015.015248    8     256
# 3             4  1564.198571  1548.230357    15.4  1595.779108   16     512
# 4             5  1564.198571  1548.230357    13.3  1015.015248    8     256
# ...         ...          ...          ...     ...          ...  ...     ...
# 1298       1316  1086.384444  1282.401653    14.0  1595.779108    4     128
# 1299       1317  1086.384444  1282.401653    13.3  1595.779108   16     512
# 1300       1318  1086.384444   782.078624    14.0   312.236375    2      64
# 1301       1319  1067.774854   782.078624    15.6  1595.779108    6    1024
# 1302       1320  1104.169367   782.078624    15.6   312.236375    4     500
#
# ...

# %%
data = target_encoding(data, 'Cpu')

# %% [markdown]
# ### Обработка Memory_Type

# %%
data = target_encoding(data, 'Memory_Type')

# %% [markdown]
# ### Обработка Gpu

# %%
data['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# AMD Radeon R7 Graphics       1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %%
data['Gpu'] = data['Gpu'].apply(lambda x: ' '.join(x.split(' ')[0:3]))

# %%
data = target_encoding(data, 'Gpu')

# %%
data
# Out:
#       laptop_ID      Company     TypeName  Inches          Cpu  Ram  Memory  \
# 0             1  1564.198571  1548.230357    13.3  1015.015248    8     128
# 1             2  1564.198571  1548.230357    13.3  1015.015248    8     128
# 2             3  1067.774854   782.078624    15.6  1015.015248    8     256
# 3             4  1564.198571  1548.230357    15.4  1595.779108   16     512
# 4             5  1564.198571  1548.230357    13.3  1015.015248    8     256
# ...         ...          ...          ...     ...          ...  ...     ...
# 1298       1316  1086.384444  1282.401653    14.0  1595.779108    4     128
# 1299       1317  1086.384444  1282.401653    13.3  1595.779108   16     512
# 1300       1318  1086.384444   782.078624    14.0   312.236375    2      64
# 1301       1319  1067.774854   782.078624    15.6  1595.779108    6    1024
# 1302       1320  1104.169367   782.078624    15.6   312.236375    4     500
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   laptop_ID    1303 non-null   int64
#  1   Company      1303 non-null   object
#  2   TypeName     1303 non-null   object
#  3   Inches       1303 non-null   float64
#  4   Cpu          1303 non-null   object
#  5   Ram          1303 non-null   int64
#  6   Memory       1303 non-null   int64
#  7   Gpu          1303 non-null   object
#  8   OpSys        1303 non-null   object
#  9   Weight       1303 non-null   float64
#  10  Price_euros  1303 non-null   float64
#  11  Memory_Type  1303 non-null   object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 122.3+ KB

# %%
data.to_csv('prepared_data.csv')
